# %%
import smtplib
# sender_email = input("Please Enter Your Email: ")
sender_email='gollavishnuyadav1@gmail.com'
# password = input("Please Enter Your Password: ")
password='lbdkvikvypfqgbsz'
recipient_email = input("Please Enter Recipient Email: ")
message = "THANK YOU FOR LOGIN  BOOK MY SHOW APPLICATION"
server = smtplib.SMTP_SSL('smtp.gmail.com',465)
server.login(sender_email, password)
server.sendmail(sender_email, recipient_email, message)
server.quit()
# Out:
# (221,
#  b'2.0.0 closing connection i16-20020a17090332d000b001b8b73da7b1sm3013381plr.227 - gsmtp')

# %%
print('WELCOME TO BOOKMYSHOW APPLICATION')
print('PLEASE LOGIN FOR BOOKING TICKETS')
print('TICKET RATES \n','KUSHI--->100\n','GABBAR-->200\n','BRO----->300\n')
print('SELECT YOUR FAVOURITE MOVIE\n','1)KUSHI\n','2)GABBAR\n','3)BRO\n')
import smtplib
# sender_email = input("Please Enter Your Email: ")
sender_email='gollavishnuyadav1@gmail.com'
# password = input("Please Enter Your Password: ")
password='lbdkvikvypfqgbsz'
recipient_email = input("Please Enter Recipient Email: ")
message = "THANK YOU FOR LOGIN  BOOK MY SHOW APPLICATION"
server = smtplib.SMTP_SSL('smtp.gmail.com',465)
server.login(sender_email, password)
server.sendmail(sender_email, recipient_email, message)
server.quit()
import emoji
def SingleTon(arg):
    x={'Kushi':100,'Bro':200,'Gabbar':300}
    print(x)
    """MEGA MULTIPLEX DEVELOPED BY VISHNU YADAV"""
    d={}
    def inner():
        if arg not in d:
            d[arg]=arg()
        return d[arg]
    return inner
@SingleTon
class Kushi():
    dd={}
    def __init__(self):
        self.tickets=200
        self.a=0
        self.b=0
    def booking(self,n):
        if self.tickets>=n:
            self.tickets-=n
            self.a+=1
            self.b+=1
            thumbs_up = emoji.emojize(":thumbs_up:")
            print(self.tickets,thumbs_up)
        else:
            thumbs_up = emoji.emojize(":thumbs_down:")
            print(thumbs_up,'NOT SUFFIECIENT TICKETS')
@SingleTon
class Bro():
    dd={}
    def __init__(self):
        self.tickets=200
        self.a=0
        self.b=0
    def booking(self,n):
        if self.tickets>=n:
            self.tickets-=n
            self.a+=1
            self.b+=1
            thumbs_up = emoji.emojize(":thumbs_up:")
            print(self.tickets,thumbs_up)
        else:
            thumbs_up = emoji.emojize(":thumbs_down:")
            print(thumbs_up,'NOT SUFFIECIENT TICKETS')
@SingleTon
class Gabbar():
    dd={}
    def __init__(self):
        self.tickets=200
        self.a=0
        self.b=0
    def booking(self,n):
        if self.tickets>=n:
            self.tickets-=n
            self.a+=1
            self.b+=1
            thumbs_up = emoji.emojize(":thumbs_up:")
            print(self.tickets,thumbs_up,'TICKETS CONFIRMED')
        else:
            thumbs_up = emoji.emojize(":thumbs_down:")
            print(thumbs_up,'NOT SUFFIECIENT TICKETS')
Vishnu=Kushi()
Mahesh=Bro()
Ram=Kushi()
Rock=Kushi()
Yadav=Bro()
Pawan=Gabbar()
Vishnu.booking(30)
Ram.booking(20)
Pawan.booking(40)
Pawan.booking(10)
Rock.booking(23)
Pawan.booking(400)
Mahesh.booking(10)
Mahesh.booking(10)
Vishnu.booking(30)
l=[]
xx=Vishnu.a
xy=Yadav.b
zz=Pawan.b
l.append(xx)
l.append(xy)
l.append(zz)
import matplotlib.pyplot as plt
x = ['Kushi', 'Bro', 'Gabbar']
cc=['red','blue','orange']
plt.bar(x, l,width=0.1,color=cc)
plt.legend(['Kush','gabbar'])
plt.title('MEGA MULTIPLEX MOVIES')
plt.show()
# Out:
# WELCOME TO BOOKMYSHOW APPLICATION
# PLEASE LOGIN FOR BOOKING TICKETS
# TICKET RATES
#  KUSHI--->100
#  GABBAR-->200
#  BRO----->300
#
# SELECT YOUR FAVOURITE MOVIE
#  1)KUSHI
#  2)GABBAR
#  3)BRO
# ---------------------------------------------------------------------------
# SMTPRecipientsRefused                     Traceback (most recent call last)
# Cell In[164], line 14
#      12 server = smtplib.SMTP_SSL('smtp.gmail.com',465)
#      13 server.login(sender_email, password)
# ---> 14 server.sendmail(sender_email, recipient_email, message)
#      15 server.quit()
#      16 import emoji
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\smtplib.py:901, in SMTP.sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     898 if len(senderrs) == len(to_addrs):
#     899     # the server refused all our recipients
#     900     self._rset()
# --> 901     raise SMTPRecipientsRefused(senderrs)
# ...

# %%
class CredentialError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg
class InsufficientBalanceError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg

class Bank:
    Name=input('name')
    if Name=='Kushi':
        def transfer_amount(amount):
            try:
                user.Withdraw(amount)
                I1.Deposited(amount)
                return True
            except:
                return False
    if Name=='Kushi':
        def transfer_amount(acc_1, acc_2, amount):
            try:
                user.Withdraw(amount)
                I1.Deposited(amount)
                return True
            except:
                return False
    if Name=='Kushi':
        def transfer_amount(acc_1, acc_2, amount):
            try:
                user.Withdraw(amount)
                I1.Deposited(amount)
                return True
            except:
                return False
    Bname='ICICI'
    def __init__(self,Name,Bal,Pin):
        self.Name=Name
        self.Bal=Bal
        self.Pin=Pin
    def Checkbalance(self):
        try:
            if self.Pin==self.getpin():
                print(self.Bal)
            else:
                raise CredentialError('INCORRECT PASSWORD')
        except CredentialError as c:
            print(c)
    def Deposited(self,amt):
        try:
            if self.Pin==self.getpin():
                self.Bal+=amt
                print('DEPOSITED MONEY SUCCESSFULLY!!!')
            else:
                raise CredentialError('INCORRECT PASSWORD')
        except CredentialError as c:
            print(c)
    def Withdraw(self,amt):
        try:
            if self.Pin==self.getpin():
                if self.Bal>=amt:
                    self.Bal-=amt
                    print(self.Bal)
                else:
                    raise InsufficientBalanceError('INSUFFICIENT BALANCE')
            else:
                raise CredentialError('INCORRECT PASSWORD')
        except (InsufficientBalanceError,CredentialError) as I:
            print(I)
    @staticmethod
    def getpin():
        return int(input())
# Name=input('')
# if Name=='Kushi':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             user.Withdraw(amount)
#             I1.Deposited(amount)
#             return True
#         except:
#             return False
# if Name=='Kushi':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             user.Withdraw(amount)
#             I1.Deposited(amount)
#             return True
#         except:
#             return False
# if Name=='Kushi':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             user.Withdraw(amount)
#             I1.Deposited(amount)
#             return True
#         except:
#             return False

I1=Bank('Kushi',0,1234)
I2=Bank('Bro',0,1234)
I3=Bank('Gabbr',0,1234)
user=Bank('Vishnu',1000,1234)
print(I1.Checkbalance())
print(user.Checkbalance())
# Out:
# 0
# None
# 1000
# None

# %%
# Out:
# {'1': 30}

# %%
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0

    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise ValueError("Insufficient Funds")

    def deposit(self, amount):
        self.balance += amount

def transfer_amount(acc_1, acc_2, amount):
    try:
        acc_1.withdraw(amount)
        acc_2.deposit(amount)
        return True
    except:
        return False
user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(25)
user_2.deposit(100)

print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
print(transfer_amount(user_1, user_2, 10))
print("Transferring 50/- from User 1 to User 2")
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
# Out:
# User 1 Balance: 25/-
# User 2 Balance: 100/-
# True
# Transferring 50/- from User 1 to User 2
# User 1 Balance: 15/-
# User 2 Balance: 110/-

# %%
class CredentialError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg
class InsufficientBalanceError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg

class Bank:
    # if Name=='Kushi':
    #     def transfer_amount(acc_1, acc_2, amount):
    #         try:
    #             user.Withdraw(amount)
    #             I1.Deposited(amount)
    #             return True
    #         except:
    #             return False
    # if Name=='Kushi':
    #     def transfer_amount(acc_1, acc_2, amount):
    #         try:
    #             user.Withdraw(amount)
    #             I1.Deposited(amount)
    #             return True
            # except:
            #     return False
    Bname='ICICI'
    def __init__(self,Name,Bal,Pin):
        self.Name=Name
        self.Bal=Bal
        self.Pin=Pin
    def Checkbalance(self):
        try:
            if self.Pin==self.getpin():
                print(self.Bal)
            else:
                raise CredentialError('INCORRECT PASSWORD')
        except CredentialError as c:
            print(c)
    def Deposited(self,amt):
        # try:
        #     if self.Pin==self.getpin():
                self.Bal+=amt
                print(self.Bal)
        #         print('DEPOSITED MONEY SUCCESSFULLY!!!')
        #     else:
        #         raise CredentialError('INCORRECT PASSWORD')
        # except CredentialError as c:
        #     print(c)
    def Withdraw(self,amt):
        try:
            if self.Pin==self.getpin():
                if self.Bal>=amt:
                    self.Bal-=amt
                    print(self.Bal)
                else:
                    raise InsufficientBalanceError('INSUFFICIENT BALANCE')
            else:
                raise CredentialError('INCORRECT PASSWORD')
        except (InsufficientBalanceError,CredentialError) as I:
            print(I)
    def transfer_amount(user,I1,amount):
        try:
            Name=input('name')
            if Name=='Kushi':
                user.Withdraw(amount)
        except:
            print('good')
    @staticmethod
    def getpin():
        return int(input('Enter Password'))
# Name=input('')
# if Name=='Kushi':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             user.Withdraw(amount)
#             I1.Deposited(amount)
#             return True
#         except:
#             return False
# if Name=='Kushi':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             user.Withdraw(amount)
#             I1.Deposited(amount)
#             return True
#         except:
#             return False
# if Name=='Kushi':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             user.Withdraw(amount)
#             I1.Deposited(amount)
#             return True
#         except:
#             return False

I1=Bank('Kushi',0,1234)
I2=Bank('Bro',0,1234)
I3=Bank('Gabbr',0,1234)
user=Bank('Vishnu',1000,1234)
mm=int(input())
Bank.transfer_amount(I1,user,mm)
print(I1.Checkbalance())
print(user.Checkbalance())
print(I1.Deposited(mm))
# Out:
# INSUFFICIENT BALANCE
# 0
# None
# 1000
# None
# 1234
# None

# %%
print('TICKET RATES \n','KUSHI--->100\n','GABBAR-->200\n','BRO----->300\n')
print('SELECT YOUR FAVOURITE MOVIE\n','1)KUSHI\n','2)GABBAR\n','3)BRO\n')
class CredentialError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg
class InsufficientBalanceError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0
    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise InsufficientBalanceError("Insufficient Funds")
    def deposit(self, amount):
        self.balance += amount
# n=input()
# if n=='Kushi':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             acc_1.withdraw(amount)
#             acc_2.deposit(amount)
#             return True
#         except:
#             return False
# if n=='Gabbar':
#     def transfer_amount(acc_1, acc_2, amount):
#         try:
#             acc_1.withdraw(amount)
#             acc_2.deposit(amount)
#             return True
#         except InsufficientBalanceError as I:
#             print(I)
KUSHI  = BankAccount("002")
GABBAR = BankAccount("003")
BRO    = BankAccount("004")
user_1 = BankAccount("001")
user_1.deposit(2500)
KUSHI.deposit(0)
GABBAR.deposit(0)
BRO.deposit(0)

n=input()
if n=='KUSHI':
    
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except:
            return False
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
    print(transfer_amount(user_1, KUSHI, 10))
    print("Transferring 100/- from User 1 to KUSHI")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
if n=='GABBAR':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except InsufficientBalanceError as I:
            print(I)

    print(transfer_amount(user_1, GABBAR, 150))
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR Balance: {}/-".format(GABBAR.get_balance()))
    print("Transferring 200- from User 1 to GABBAR")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR 2 Balance: {}/-".format(GABBAR.get_balance()))
# Out:
# TICKET RATES
#  KUSHI--->100
#  GABBAR-->200
#  BRO----->300
#
# SELECT YOUR FAVOURITE MOVIE
#  1)KUSHI
#  2)GABBAR
#  3)BRO
#
# True
# User 1 Balance: 2350/-
# GABBAR Balance: 150/-
# Transferring 200- from User 1 to GABBAR
# User 1 Balance: 2350/-
# GABBAR 2 Balance: 150/-

# %%
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0

    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise ValueError("Insufficient Funds")

    def deposit(self, amount):
        self.balance += amount


# def transfer_amount(acc_1, acc_2, amount):
#     try:
#         acc_1.withdraw(amount)
#         acc_2.deposit(amount)
#         return True
#     except:
#         return False


user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(25)
user_2.deposit(100)
def transfer_amount(acc_1, acc_2, amount):
    try:
        acc_1.withdraw(amount)
        acc_2.deposit(amount)
        return True
    except:
        return False
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
print(transfer_amount(user_1, user_2, 50))
print("Transferring 50///- from User 1 to User 2")
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
# Out:
# User 1 Balance: 25/-
# User 2 Balance: 100/-
# False
# Transferring 50/- from User 1 to User 2
# User 1 Balance: 25/-
# User 2 Balance: 100/-

# %%
# Out:
# TICKET RATES
#  KUSHI--->100
#  GABBAR-->200
#  BRO----->300
#
# SELECT YOUR FAVOURITE MOVIE
#  1)KUSHI
#  2)GABBAR
#  3)BRO
#
# Insufficient Funds
# None
# User 1 Balance: 0/-
# GABBAR Balance: 0/-
# Transferring 200- from User 1 to GABBAR
# User 1 Balance: 0/-
# GABBAR 2 Balance: 0/-

# %%
print('TICKET RATES \n','KUSHI--->100\n','GABBAR-->200\n','BRO----->300\n')
print('SELECT YOUR FAVOURITE MOVIE\n','1)KUSHI\n','2)GABBAR\n','3)BRO\n')
class CredentialError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg
class InsufficientBalanceError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg

class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0
        self.money=0
    def get_balance(self):
        return self.balance
    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise InsufficientBalanceError("Insufficient Funds")
    def deposit(self, amount):
        self.balance += amount
        self.money+=150
KUSHI  = BankAccount("002")
GABBAR = BankAccount("003")
BRO    = BankAccount("004")
user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(250)
user_2.deposit(200)
KUSHI.deposit(0)
GABBAR.deposit(0)
BRO.deposit(0)
n=input()
if n=='KUSHI':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except:
            return False
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
    print(transfer_amount(user_1, KUSHI, 100))
    print("Transferring 100/- from User 1 to KUSHI")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
if n=='GABBAR':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except InsufficientBalanceError as I:
            print(I)
    print(transfer_amount(user_2, GABBAR, 150))
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR Balance: {}/-".format(GABBAR.get_balance()))
    print("Transferring 200/- from User 1 to GABBAR")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR  Balance: {}/-".format(GABBAR.get_balance()))
if n=='BRO':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except InsufficientBalanceError as I:
            print(I)
    print(transfer_amount(user_2, GABBAR, 150))
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR Balance: {}/-".format(BRO.get_balance()))
    print("Transferring 200- from User 1 to GABBAR")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR 2 Balance: {}/-".format(BRO.get_balance()))
# Out:
# TICKET RATES
#  KUSHI--->100
#  GABBAR-->200
#  BRO----->300
#
# SELECT YOUR FAVOURITE MOVIE
#  1)KUSHI
#  2)GABBAR
#  3)BRO
#
# True
# User 1 Balance: 250/-
# GABBAR Balance: 150/-
# Transferring 200/- from User 1 to GABBAR
# User 1 Balance: 250/-
# GABBAR  Balance: 150/-

# %%
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0

    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise ValueError("Insufficient Funds")

    def deposit(self, amount):
        self.balance += amount


def transfer_amount(acc_1, acc_2, amount):
    try:
        acc_1.withdraw(amount)
        acc_2.deposit(amount)
        return True
    except:
        return False


user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(25)
user_2.deposit(100)

print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
print(transfer_amount(user_1, user_2, 50))
print("Transferring 50/- from User 1 to User 2")
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
# Out:
# User 1 Balance: 25/-
# User 2 Balance: 100/-
# False
# Transferring 50/- from User 1 to User 2
# User 1 Balance: 25/-
# User 2 Balance: 100/-

# %%
class CredentialError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg
class InsufficientBalanceError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg

class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0
        self.money=0
    def get_balance(self):
        return self.balance
    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise InsufficientBalanceError("Insufficient Funds")
    def deposit(self, amount):
        self.balance += amount
        self.money+=150
KUSHI  = BankAccount("002")
GABBAR = BankAccount("003")
BRO    = BankAccount("004")
user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(250)
user_2.deposit(200)
KUSHI.deposit(0)
GABBAR.deposit(0)
BRO.deposit(0)
n=input()
if n=='KUSHI':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except:
            return False
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
    print(transfer_amount(user_1, KUSHI, 100))
    print("Transferring 100/- from User 1 to KUSHI")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
if n=='GABBAR':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except InsufficientBalanceError as I:
            print(I)
    print(transfer_amount(user_2, GABBAR, 150))
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR Balance: {}/-".format(GABBAR.get_balance()))
    print("Transferring 200/- from User 1 to GABBAR")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR  Balance: {}/-".format(GABBAR.get_balance()))
if n=='BRO':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except InsufficientBalanceError as I:
            print(I)
    print(transfer_amount(user_2, BRO, 150))
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR Balance: {}/-".format(BRO.get_balance()))
    print("Transferring 200- from User 1 to BRO")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR 2 Balance: {}/-".format(BRO.get_balance()))
    print(KUSHI.money)
# Out:
# True
# User 1 Balance: 250/-
# GABBAR Balance: 150/-
# Transferring 200/- from User 1 to GABBAR
# User 1 Balance: 250/-
# GABBAR  Balance: 150/-

# %%
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0

    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise ValueError("Insufficient Funds")

    def deposit(self, amount):
        self.balance += amount


def transfer_amount(acc_1, acc_2, amount):
    try:
        acc_1.withdraw(amount)
        acc_2.deposit(amount)
        return True
    except:
        return False


user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(25)
user_2.deposit(100)

print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
print(transfer_amount(user_1, user_2, 50))
print("Transferring 50/- from User 1 to User 2")
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
# Out:
# User 1 Balance: 25/-
# User 2 Balance: 100/-
# False
# Transferring 50/- from User 1 to User 2
# User 1 Balance: 25/-
# User 2 Balance: 100/-

# %%
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0

    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise ValueError("Insufficient Funds")

    def deposit(self, amount):
        self.balance += amount


def transfer_amount(acc_1, acc_2, amount):
    try:
        acc_1.withdraw(amount)
        acc_2.deposit(amount)
        return True
    except:
        return False


user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(25)
user_2.deposit(100)

print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
print(transfer_amount(user_1, user_2, 10))
print("Transferring 50/- from User 1 to User 2")
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
# Out:
# User 1 Balance: 25/-
# User 2 Balance: 100/-
# True
# Transferring 50/- from User 1 to User 2
# User 1 Balance: 15/-
# User 2 Balance: 110/-

# %%
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0

    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise ValueError("Insufficient Funds")

    def deposit(self, amount):
        self.balance += amount


def transfer_amount(acc_1, acc_2, amount):
    try:
        acc_1.withdraw(amount)
        acc_2.deposit(amount)
        return True
    except:
        return False


user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(25)
user_2.deposit(100)

print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
print(transfer_amount(user_1, user_2, 50))
print("Transferring 50/- from User 1 to User 2")
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
# Out:
# User 1 Balance: 25/-
# User 2 Balance: 100/-
# False
# Transferring 50/- from User 1 to User 2
# User 1 Balance: 25/-
# User 2 Balance: 100/-

# %%
class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0

    def get_balance(self):
        return self.balance

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise ValueError("Insufficient Funds")

    def deposit(self, amount):
        self.balance += amount


def transfer_amount(acc_1, acc_2, amount):
    try:
        acc_1.withdraw(amount)
        acc_2.deposit(amount)
        return True
    except:
        return False


user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(25)
user_2.deposit(100)

print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
print(transfer_amount(user_1, user_2,   10))
print("Transferring 50/- from User 1 to User 2")
print("User 1 Balance: {}/-".format(user_1.get_balance()))
print("User 2 Balance: {}/-".format(user_2.get_balance()))
# Out:
# User 1 Balance: 25/-
# User 2 Balance: 100/-
# True
# Transferring 50/- from User 1 to User 2
# User 1 Balance: 15/-
# User 2 Balance: 110/-

# %%
print('WELCOME TO BOOKMYSHOW APPLICATION')
print('PLEASE LOGIN FOR BOOKING TICKETS')
print('TICKET RATES \n','KUSHI--->100\n','GABBAR-->200\n','BRO----->300\n')
print('SELECT YOUR FAVOURITE MOVIE\n','1)KUSHI\n','2)GABBAR\n','3)BRO\n')
import smtplib
# sender_email = input("Please Enter Your Email: ")
sender_email='gollavishnuyadav1@gmail.com'
# password = input("Please Enter Your Password: ")
password='lbdkvikvypfqgbsz'
# recipient_email = input("Please Enter Recipient Email: ")
recipient_email='gollavishnuyadav2@gmail.com'
message = "THANK YOU FOR LOGIN  BOOK MY SHOW APPLICATION"
server = smtplib.SMTP_SSL('smtp.gmail.com',465)
server.login(sender_email, password)
server.sendmail(sender_email, recipient_email, message)
server.quit()
import emoji
def SingleTon(arg):
    """MEGA MULTIPLEX DEVELOPED BY VISHNU YADAV"""
    d={}
    def inner():
        if arg not in d:
            d[arg]=arg()
        return d[arg]
    return inner
@SingleTon
class Kushi():
    dd={}
    def __init__(self):
        self.tickets=200
        self.a=0
        self.b=0
    def booking(self,n):
        if self.tickets>=n:
            self.tickets-=n
            self.a+=1
            self.b+=1
            thumbs_up = emoji.emojize(":thumbs_up:")
            print('TICKETS CONFIRMED',thumbs_up)
        else:
            thumbs_up = emoji.emojize(":thumbs_down:")
            print(thumbs_up,'NOT SUFFIECIENT TICKETS')
@SingleTon
class Bro():
    dd={}
    def __init__(self):
        self.tickets=200
        self.a=0
        self.b=0
    def booking(self,n):
        if self.tickets>=n:
            self.tickets-=n
            self.a+=1
            self.b+=1
            thumbs_up = emoji.emojize(":thumbs_up:")
            print('TICKETS CONFIRMED',thumbs_up)
        else:
            thumbs_up = emoji.emojize(":thumbs_down:")
            print(thumbs_up,'NOT SUFFIECIENT TICKETS')
@SingleTon
class Gabbar():
    dd={}
    def __init__(self):
        self.tickets=200
        self.a=0
        self.b=0
    def booking(self,n):
        if self.tickets>=n:
            self.tickets-=n
            self.a+=1
            self.b+=1
            thumbs_up = emoji.emojize(":thumbs_up:")
            print('TICKETS CONFIRMED',thumbs_up,'TICKETS CONFIRMED')
        else:
            thumbs_up = emoji.emojize(":thumbs_down:")
            print(thumbs_up,'NOT SUFFIECIENT TICKETS')
class CredentialError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg
class InsufficientBalanceError(BaseException):
    def __init__(self,msg):
        self.msg=msg
    def __str__(self):
        return self.msg

class BankAccount:
    def __init__(self, account_number):
        self.account_number = str(account_number)
        self.balance = 0
        self.money=0
    def get_balance(self):
        return self.balance
    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            raise InsufficientBalanceError("Insufficient Funds")
    def deposit(self, amount):
        self.balance += amount

KUSHI  = BankAccount("002")
GABBAR = BankAccount("003")
BRO    = BankAccount("004")
user_1 = BankAccount("001")
user_2 = BankAccount("002")
user_1.deposit(250)
user_2.deposit(200)
KUSHI.deposit(0)
GABBAR.deposit(0)
BRO.deposit(0)
n=input()
if n=='KUSHI':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except:
            return False
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
    print(transfer_amount(user_1, KUSHI, 100))
    print("Transferring 100/- from User 1 to KUSHI")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("KUSHI Balance: {}/-".format(KUSHI.get_balance()))
if n=='GABBAR':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except InsufficientBalanceError as I:
            print(I)
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR Balance: {}/-".format(GABBAR.get_balance()))
    print("Transferring 200/- from User 1 to GABBAR")
    print(transfer_amount(user_1, GABBAR, 15))
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR  Balance: {}/-".format(GABBAR.get_balance()))
if n=='BRO':
    def transfer_amount(acc_1, acc_2, amount):
        try:
            acc_1.withdraw(amount)
            acc_2.deposit(amount)
            return True
        except InsufficientBalanceError as I:
            print(I)
    print(transfer_amount(user_2, BRO, 150))
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR Balance: {}/-".format(BRO.get_balance()))
    print("Transferring 200- from User 1 to BRO")
    print("User 1 Balance: {}/-".format(user_1.get_balance()))
    print("GABBAR 2 Balance: {}/-".format(BRO.get_balance()))
    print(KUSHI.money)
Vishnu=Kushi()
Mahesh=Bro()
Ram=Kushi()
Pawan=Gabbar()
Vishnu.booking(30)
Pawan.booking(10)
Mahesh.booking(10)
Vishnu.booking(3)
l=[]
xx=Vishnu.a
xy=Mahesh.b
zz=Pawan.b
l.append(xx)
l.append(xy)
l.append(zz)
from matplotlib import pyplot as plt
x = ['Kushi', 'Bro', 'Gabbar']
cc=['red','blue','orange']
plt.bar(x, l,width=0.1,color=cc)
plt.title('MULTIPLEX MOVIES')
plt.show()
m_v=['KUSHI','GABBAR','BRO']
c_o=[300,150,90]
plt.pie(c_o,labels=m_v,startangle=180,explode=[0.1,0,0],shadow=True,colors=['red','orange','blue'],autopct="%5.1f%%")
plt.legend(title='COLLECTIONS')
plt.figure(figsize=(15,20))
# Out:
# WELCOME TO BOOKMYSHOW APPLICATION
# PLEASE LOGIN FOR BOOKING TICKETS
# TICKET RATES
#  KUSHI--->100
#  GABBAR-->200
#  BRO----->300
#
# SELECT YOUR FAVOURITE MOVIE
#  1)KUSHI
#  2)GABBAR
#  3)BRO
#
# User 1 Balance: 250/-
# GABBAR Balance: 0/-
# Transferring 200/- from User 1 to GABBAR
# True
# User 1 Balance: 235/-
# GABBAR  Balance: 15/-
# TICKETS CONFIRMED 👍
# TICKETS CONFIRMED 👍 TICKETS CONFIRMED
# TICKETS CONFIRMED 👍
# TICKETS CONFIRMED 👍

# %%
# Python3 code to demonstrate working of
# Mirror Image of String
# Using Mirror Image of String

# initializing strings
test_str = 'void'

# printing original string
print("The original string is : " + str(test_str))

# initializing mirror dictionary
mir_dict = {'b':'d', 'd':'b', 'i':'i', 'o':'o', 'v':'v', 'w':'w', 'x':'x'}
res = ''

# accessing letters from dictionary
for ele in test_str:
	if ele in mir_dict:
		res += mir_dict[ele]
	
	# if any character not present, flagging to be invalid
	else:
		res = "Not Possible"
		break

# printing result
print("The mirror string : " + str(res))
# Out:
# The original string is : void
# The mirror string : voib

# %%
T='Geeksforgeeks is best for geeks and CS'.split()
S='Geeksforgeeks is gfg gfg geeks and gfg'
l=['best','CS','for']
m='gfg'
res=''
for i in T:
    if i in l:
        res=res+i+m
    res+=i
res
# Out:
# 'GeeksforgeeksisbestgfgbestforgfgforgeeksandCSgfgCS'

# %%
T='Geeksforgeeks is best for geeks and CS'
S='Geeksforgeeks is gfg gfg geeks and gfg'
l='best for geeks'
import re
xx=re.sub('best','gfg',T)
yy=re.sub('for','gfg',xx)
zz=re.sub('CS','gfg',yy)
zz
# Out:
# 'Geeksgfggeeks is gfg gfg geeks and gfg'

# %%
T='Geeksforgeeks is best for geeks and CS'
S='Geeksforgeeks is gfg gfg geeks and gfg'
l='best for CS'.split()
for i in l:
    T=T.replace(i,'gfg')
print(T)
# Out:
# Geeksgfggeeks is gfg gfg geeks and gfg

# %%
r = 'geeksforgeeks is best'
# map_dict = {'e':'1', 'b':'6'}
# Output : g11ksforg11ks is 61st 
# Explanation : All e are replaced by 1 and b by 6.
import re
r=re.sub('e','1',r)
r=re.sub('b','6',r)
r
# Out:
# 'g11ksforg11ks is 61st'

# %%
import speech_recognition as aa
import pyttsx3
import pywhatkit
import datetime
import wikipedia
listener=aa.Recognizer()
machine=pyttsx3.init()
def talk(text):
    machine.say(text)
    machine.runAndWait()
def input_instruction():
    try:
        with aa.Microphone() as origin:
            print('PLEASE TELL ME WHAT YOU WANT')
            speech = listener.listen(origin)
            instruction = listener.recognize_google(speech)
            instruction = instruction.lower()
            print(instruction)
            if 'bro' in instruction:
                instruction = instruction.replace('baby', '')
            print(instruction)
    except:
        pass
    return instruction


def pl():
    instruction=input_instruction()
    print(instruction)
    if 'play' in instruction:
        song=instruction.replace('play', " ")
        talk('playing' + song)
        pywhatkit.playonyt(song)
    if 'time' in instruction:
        time=datetime.datetime.now().strftime('%I:%M%p')
        talk('Current time'+time)
    elif 'date' in instruction:
        date=datetime.datetime.now().strftime('%d /%m /%Y')
        talk('Todays date'+date)
    elif 'how are you' in instruction:
        talk('Iam Fine,How about You')
    elif "your name" in instruction:
        talk('My name is POWER STAR,What can i do for you?')
    elif 'who is' in instruction:
        human=instruction.replace('who is'," ")
        info=wikipedia.summary(human,1)
        print(info)
        talk(info)
    elif 'who is jango trainer' in instruction:
        talk('HARSHADH SIR')
    elif 'bro say hello to sir' in instruction:
        talk('HELLO HARSHADH SIR HOW ARE YOU')
    else:
        talk('plaese repeat')
pl()
