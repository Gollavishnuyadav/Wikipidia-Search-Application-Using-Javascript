# %%
n=5
for i in range(n):
    for j in range(n):
        if i==0 and j!=n-1 and j!=0 or j==0 and i!=0 or j==n-1 and i!=0 and i!=0 or i==n//2:
            print('a',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
#   a a a
# a       a
# a a a a a
# a       a
# a       a

# %%
n=5
for i in range(5):#outer row
    for j in range(5):#inner column
        if i==0:
            print('*',end=' ')
        else:
            print(' ',end=' ')

    print()
# Out:
# * * * * *

# %%
n=5
for i in range(2,n//2+1):
    if n%i==0:
        break
else:
    print('prime')
# Out:
# prime

# %%
def sum(n):
    res=0
    while n!=0:
        rem=n%10
        n//=10
        res=res+rem
    print(res)
sum(123)
# Out:
# 6

# %%
def sum(n):
    res=1
    while n!=0:
        rem=n%10
        n//=10
        res=res*rem
    print(res)
sum(123)
# Out:
# 6

# %%
n=4
for i in range(2,n//2+1):
    if n%i==0:
        print('composite')
    else:
        print('not')
# Out:
# composite

# %%
n=132
num=n
res=0
while n!=0:
    rem=n%10
    n//=10
    res=res+rem
if num%res==0:
    print('Niven')
else:
    print('Not Niven')
# Out:
# Niven

# %%
def sum(n):
    if n==0:
        return 0
    return n%10+sum(n//10)
nn=sum(132)
# Out:
# 6

# %%
def Com(n,i):
    if i==n//2+1:
        return 0
    if n%i==0:
        print(i)
        Com(n,i+1)
obj=Com(12,2)
# Out:
# 2
# 3
# 4

# %%
# Out:
# 2543
# 4253
# 4523

# %%
nn=12345
res=0
while nn!=0:
    rem=n%10
    print(rem)
    nn//=10
    # if rem>1:
    #     for i in range(2,rem//2+1):
    #         if rem%i==0:
    #             break
    #     else:
    #         print(rem)
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
n=1234
while n!=0:
    rem=n%10
    n//=10
    if rem>1:
        for i in range(2,rem//2+1):
            if rem%i==0:
                break
        else:
            print(rem)
# Out:
# 3
# 2

# %%
def prime(n,i):
    if i==n-1:
        return False
    if n%i==0 or n==1:
        return False
    if n==2:
        return True
    prime(n,i+1)
if prime(2,2):
    print('not')
else:
    print('not')
# Out:
# not

# %%
def factorial(n):
    fact=1
    for i in range(1,n+1):
        fact=fact*i
    return fact
obj=factorial(10)
obj
# Out:
# 3628800

# %%
for i in range(20,30):
    if i>1:
        for j in range(2,i//2+1):
            if i%j==0:
                break
        else:
            print(j)
# Out:
# 11
# 14

# %%
n=135
num=n
res=0
p=len(str(n))
while n!=0:
    rem=n%10
    n//=10
    res=res+rem**p
    p=p-1

if res==num:
    print('Disarum')
else:
    print('not Disarum')
# Out:
# Disarum

# %%
s=[5,9,2,8,7,6]
for i in range(len(s)):
    for j in range(1,len(s)):
        if s[i]+s[j]==10:
            print(s[i],s[j])
# Out:
# 2 8
# 8 2

# %%
'Python Program to Count the Number of Words in a Text File'
x=open('an.txt','w')
x.write('This tutorial will show you how to use Python to count the number of words in a file. One Python program will be written to count the total number of words in a text file. The path to the file will be passed to the application as an input. This tutorial will teach you how to open a file and read its contents in Python. You’ll also learn how to get a list of all the words in a string.')
x.close()

# %%
x=open('a.txt','r')
xx=x.read().split()
print(len(xx))
# Out:
# 80

# %%
x=open('an.txt','r')
c=0
l=[]
o=x.readlines()
for i in o:
    l.append(i)
print(len(l))
# Out:
# 7

# %%
#Give the string as static input and store it in a variable.
givenstring=input('Enter some random string = ')
#Enter the file name of the  file using the input() function and store it in a variable.
filename = input("Enter the first file name = ")
#In append mode, open the first file with the entered file name.
givenfile=open(filename,"a")
#Write a new line character to the given file using the write() function and '\n'.
givenfile.write("\n")
#Append the given string to the given file using the write() function.
givenfile.write(givenstring)
#Close the given file using close() function.
givenfile.close()
print('Printing the contents of the given file :')
with open(filename, 'r') as givenfile:
  #Using for loop, go over the lines in the first file.
    for fileline in givenfile:
      #print the lines
        print(fileline)
# Out:
# Printing the contents of the given file :
#
#
# hello

# %%
xx=open('an.txt','a')
c=xx.write('Hello Managment')
xx.append(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 3
#       1 xx=open('an.txt','a')
#       2 c=xx.write('Hello Managment')
# ----> 3 xx.append(c)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'append'

# %%
n="995956370363456789987654345678909876545678987654567898765678909876543234567890987654321234567890987654323456789876543456789098765456789087654321234567898765456789876543"
count=0
for i in range(len(n)):
    if n[i]=="6":
        count+=1
print(count)
# Out:
# 26

# %%
n="Somappa"
for i in range(len(n)):
    print(n[i])
# Out:
# S
# o
# m
# a
# p
# p
# a

# %%
n=int(input())
m=int(input())
print(n+m)
# Out:
# 85555790

# %%
l=[1,2,34,5,6]
for i in range(len(l)):
    if l[i]%2==0:
        print(l[i])
# Out:
# 2
# 34
# 6
