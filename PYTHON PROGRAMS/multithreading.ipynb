# %%
import time
import threading
def fun1(n):
    for i in range(n):
        print('fun1 Execution')
        time.sleep(2)
def fun2(n):
    for i in range(n):
        print('finc2 is execution')
        time.sleep(2)
t1=time.time()
th1=threading.Thread(target=fun1,args=(5,),name="Vishnu")
th2=threading.Thread(target=fun2,args=(5,),name="Yadav")
print(th1.is_alive())
print(th2.is_alive())
th1.start()
th2.start()
th1.join()
th2.join()
print(threading.active_count())
print(threading.enumerate())
print(th1.is_alive())
print(th2.is_alive())
print(th1.getName)
print(th2.getName)
t2=time.time()
t3=t1-t2
t3
# Out:
# False
# False
# fun1 Execution
# finc2 is execution
# finc2 is execution
# fun1 Execution
# fun1 Executionfinc2 is execution
#
# fun1 Executionfinc2 is execution
#
# fun1 Executionfinc2 is execution
#
# 6
# [<_MainThread(MainThread, started 15144)>, <Thread(IOPub, started daemon 14728)>, <Heartbeat(Heartbeat, started daemon 25496)>, <ControlThread(Control, started daemon 9992)>, <HistorySavingThread(IPythonHistorySavingThread, started 5292)>, <ParentPollerWindows(Thread-4, started daemon 21868)>]
# False
# False
# <bound method Thread.getName of <Thread(Vishnu, stopped 10656)>>
# <bound method Thread.getName of <Thread(Yadav, stopped 21480)>>
# -10.051007986068726
