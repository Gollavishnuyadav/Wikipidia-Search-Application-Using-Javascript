# %%
n = int(input())
m = input()
if n >= 50 and n <=100 and int(m[0]) == 7 :
    print('True')
else:
    print('False')
# Out:
# False

# %%
m = int(input())
p = int(input())
c = int(input())

if (m>=35 and p>=35 and c>=35) and (m + p >= 90 or p+c >= 90 or m + c >=90):
    print('True')
else:
    print('False')
# Out:
# False
