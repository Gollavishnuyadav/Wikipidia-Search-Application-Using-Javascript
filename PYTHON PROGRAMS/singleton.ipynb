# %%
def movie(arg):
    d={}
    def inner():
        if arg not in d:
            d[arg]=arg()
        return d[arg]
    return inner        
@movie
class kushi():
    def __init__(self):
        self.tickets=5
    def booking(self,n):
        if self.tickets>=n:
            self.tickets-=n
            print('tickets confirmed')
        else:
            print('tickets not avialable')
def bmys():
    oo=kushi()
    oo.booking(int(input()))
bmys()
bmys()
# Out:
# tickets confirmed
# tickets not avialable

# %%
def prime(n,i):
    if i==n//2+1:
        return False
    if n%2==0:
        return False
    return prime(n,i+1)
prime(3,2)
# Out:
# False

# %%
# x=[[1, 2], [3, 4], [5, 6]]
# y=[[3, 4], [5, 7], [1, 2]]
# for i in range(len(x)):
#     for j in range(len(y)):
#         if x[i]==y[j]:
#             print(x[i])
#         else:
#             print(x[i],y[j])
#             break
# Out:
# [1, 2] [3, 4]
# [3, 4]
# [3, 4] [5, 7]
# [5, 6] [3, 4]

# %%
if [1]==[1]:
    print('d')
# Out:
# d

# %%
import requests
api='6d786484fcd5ff8d85294d5588b84905'
user_input=input('Enter city:')
weather_data=requests.get(f"https://api.openweathermap.org/data/2.5/weather?q={user_input}&units=imperial&APPID={api}")
print(weather_data.status_code)
weather=weather_data.json()['weather'][0]['main']
temp=round(weather_data.json()['main']['temp'])
print(f'The weather in {user_input} is:{weather}')
print(f'The temperature in {user_input} is:{temp}*F')
# Out:
# 200
# The weather in GUNTUR is:Clouds
# The temperature in GUNTUR is:86*F

# %%
# Python code to sorting list
# according to the column

# sortarray function is defined
def sortarray(array):
	
	for i in range(len(array[0])):
		
		# sorting array in ascending
		# order specific to column i,
		# here i is the column index
		sortedcolumn = sorted(array, key = lambda x:x[i])
		
		# After sorting array Column 1
		print("Sorted array specific to column {}, \
		{}".format(i, sortedcolumn))
	
# Driver code
if __name__ == '__main__':
	
	# array of size 3 X 2
	array = [['java', 1995], ['c++', 1983],
			['python', 1989]]
	
	# passing array in sortarray function
	sortarray(array)
# Out:
# Sorted array specific to column 0, 		[['c++', 1983], ['java', 1995], ['python', 1989]]
# Sorted array specific to column 1, 		[['c++', 1983], ['python', 1989], ['java', 1995]]

# %%
def sample(n):
    for i in range(len(n[0])):
        x=sorted(n,key=lambda x:x[i])
        print(i,x)
n = [['java', 1995], ['c++', 1983],['python', 1989],['ython', 1989],['thon', 199]]
x=sample(n)
# Out:
# 0 [['c++', 1983], ['java', 1995], ['python', 1989], ['thon', 199], ['ython', 1989]]
# 1 [['thon', 199], ['c++', 1983], ['python', 1989], ['ython', 1989], ['java', 1995]]

# %%
l = ["geeks", "for", "geeks", "is", "best"]
x=[]
for i  in range(len(l)):
    l[i]=l[i][::-1]
    x.append(l[i])
x
# Out:
# ['skeeg', 'rof', 'skeeg', 'si', 'tseb']

# %%
t = ['Gfg is good for learning', 'Gfg is for geeks', 'I love G4G']
K = l
n=[]
O=['learning', 'love']
for i in t:
    for j in i.split():
        if 'l' in j:
            n.append(j)
n
# Out:
# ['learning', 'love']

# %%
s= ['gfgisbest', 'geeks', 'gfgfreak', 'gfgCS', 'Gcourses']
x=''.join(s)
import re
xx=re.findall('gfg',x)
print(len(xx))
# Out:
# 3

# %%
s=['Gfg is best', 'for Geeks', 'Preparing']
l=[]
for i in s:
    for j in i.split():
        l.append(j)
l
# Out:
# ['Gfg', 'is', 'best', 'for', 'Geeks', 'Preparing']

# %%
t = ['geeksforgeeks', 'best', 'geeks', 'and',"geeks", "love", "CS"]
l=[]
for i in range(len(t)):
    if t[i].startswith('geeks'):
        l.extend([         [t[i],t[i+1]]            ])
l
# Out:
# [['geeksforgeeks', 'best'], ['geeks', 'and'], ['geeks', 'love']]

# %%
test_list = ["geeksforgeeks", "best", "geeks", "and", "geeks", "love", "CS"]
pref = "geek"
res = []
for val in test_list:
	if val.startswith(pref):
		res.append([val])
	else:
		res[-1].append(val)
print(str(res))
# Out:
# [['geeksforgeeks', 'best'], ['geeks', 'and'], ['geeks', 'love', 'CS']]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
