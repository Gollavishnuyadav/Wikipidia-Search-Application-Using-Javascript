# %%
a=['a',2]
b=a
b.append(12)
print(id(b))
print(id(a))
# Out:
# 97524424
# 97524424

# %%
def one(a):
    a[0]=['oo']
    a[1]=['ee']
    return a
ll=['ee','oo']
lb=one(ll)
xx=id(ll)==id(lb)
print(xx)
print(id(ll))
print(id(lb))
# Out:
# True
# 104582152
# 104582152

# %%
d={'a':10,'b':20}
e=d.copy()
print(id(d))
print(id(e))
# Out:
# 104569464
# 104567904

# %%
d={'a':10,'b':20}
e=d
e['10']=1
print(d)
print(e)
# Out:
# {'a': 10, 'b': 20, '10': 1}
# {'a': 10, 'b': 20, '10': 1}

# %%
n=5
st=1
num=1
for x in range(n):
    for y in range(st):
        if x==0:
            print('1',end=' ')
        elif x==1:
            print('2',end=' ')
        elif x==2:
            print('3',end=' ')
        elif x==3:
            print('4',end=' ')
    print()
    st+=1
# Out:
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %%
n = ('on1e', 'tuo2e', 'thr4ee', 'lion0')
o = [3, 0, 1, 2]
mn = [n[i] for i in o]
print(mn)
# Out:
# ['lion0', 'on1e', 'tuo2e', 'thr4ee']

# %%
N='A1S W3E A2RE G3OING T4O'
e=0
m=N.split()
for x in m:
    while e!=len(x):
        if str(e) in x:
            print(x)
        e+=1
# Out:
# A1S
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       3 m=N.split()
#       4 for x in m:
# ----> 5     while e!=len(x):
#       6         if str(e) in x:
#       7             print(x)
#
# KeyboardInterrupt:

# %%
x=[1,2,3]
y=[5,7]
z=122
x=y
x.append(z)
print(x)
# Out:
# [5, 7, 122]

# %%
# Out:
# P
# Y
# T
# H
# O
# N

# %%
x=[15,12,10,13,18,17]
l=[]
Lowest=x[0]
for z in range(len(x)):
    if Lowest>x[z]:
        Lowest=x[z]
    else:
        l.append(x[z])
l=l[0]
for y in range(len(l)):
    if 
print(Lowest)
# Out:
# [15, 13, 18, 17]
# [15, 13, 18, 17]
# [15, 13, 18, 17]
# [15, 13, 18, 17]
# 10

# %%
class Cart:
    def __init__(self):
        self.items = {}
        self.price_details = {"book": 500, "laptop": 30000}

    def add_item(self, item_name, quantity):
        self.items[item_name] = quantity

    def remove_item(self, item_name):
        del self.items[item_name]

    def update_quantity(self, item_name, quantity):
        self.items[item_name] = quantity

    def get_cart_items(self):
        cart_items = list(self.items.keys())
        return cart_items

    def get_total_price(self):
        total_price = 0
        for item, quantity in self.items.items():
            total_price += quantity * self.price_details[item]
        return total_price
cart_obj = Cart()
cart_obj.add_item("book", 3)
cart_obj.add_item("laptop", 1)
print(cart_obj.get_total_price())
cart_obj.remove_item("laptop")
print(cart_obj.get_cart_items())
cart_obj.update_quantity("book", 2)
print(cart_obj.get_total_price())
# Out:
# 31500
# ['book']
# 1000

# %%
class Cart:
    def __init__(self):
        self.items={}
        self.price_details={'Book':2,'laptop':3900}
    def add_items(self,item,quantity):
        self.items[item]=quantity
        for i,j in self.items.items():
            print(i,j)
    def update_items(self,item,quantity):
        self.items[item]=quantity
        print(self.items.items())
    
    def delete_item(self,item):
        del self.items[item]

    def get(self):
        item=list(self.items.keys())
        return item
    
    def price(self):
        i=0
        for k,l in self.items.items():
            i+=l*self.price_details[k]
            return i
Obj=Cart()
Obj.add_items('Book',1)
Obj.update_items('laptop',3)
Obj.delete_item('Book')
Obj.get()
Obj.price()
# Out:
# Book 1
# dict_items([('Book', 1), ('laptop', 3)])
# 11700

# %%
s='aaabbbccz'
o=''
p=s[0]
c=1
i=1
while i<len(s):
    if p==s[i]:
        c+=1
    else:
        o+=str(c)+p
        p=s[i]
        c=1
    if i==len(s)-1:
        o+=str(c)+p
    i+=1
o
# Out:
# '3a3b2c1z'

# %%
s='a4k3b2'

# %%
s =['hello', 'this', 'is', 'btechgeeks', 'python', 'coding', 'platform']
s.remove('python')
s
# Out:
# ['hello', 'this', 'is', 'btechgeeks', 'coding', 'platform']

# %%
s =['hello', 'this', 'is', 'btechgeeks', 'python', 'coding', 'platform']
x=[i for i in s if i!='python']
x
# Out:
# ['hello', 'this', 'is', 'btechgeeks', 'coding', 'platform']

# %%
n='hellosir'
res=''
odd=''
for i in range(len(n)):
    if i%2==0:
        res+=n[i]
    else:
        odd+=n[i]
res,odd
# Out:
# ('hloi', 'elsr')

# %%
n='HELLO hello'
for i in n:
    if i.lower()==i:
        print(i)
# Out:
#
# h
# e
# l
# l
# o

# %%
n='rf8ss'
for i  in range(len(n)):
    if n[i].isdigit():
        print('True')
    else:
        print('False')
# Out:
# False
# False
# True
# False
# False

# %%
# Import math module using the import keyword.
import math
# Give the string as static input and store it in a variable.
gven_str = "kaka"
# Take a variable to say lexicogrpc_rank and initialize its value to 1.
lexicogrpc_rank = 1
# Calculate the length of the given string using the len() function and decrease it by 1.
# Store it in another variable say str_lengt.
str_lengt = len(gven_str)-1
# Loop from 0 to the above length using the for loop.
for itr in range(0, str_lengt):
    # Inside the loop, take a variable to say cnt and initialize its value to 0.
    cnt = 0
    # Loop from the itr+1 to the above str_lengt (where itr is the iterator value of the parent
    # for loop) using the for loop.
    for k in range(itr+1, str_lengt+1):
      # Inside the loop, check if the character present at the iterator value of the parent for
      # loop is greater than the character present at the iterator value of the inner for
      # loop using the if conditional statement.
        if gven_str[itr] > gven_str[k]:
         # If the statement is true, then increment the value of the above-initialized cnt by 1.
            cnt += 1
    # Calculate the factorial of (str_lengt - itr) using the math.factorial() function and
    # store it in another variable. (where itr is the iterator value of the parent for loop)
    f = math.factorial(str_lengt-itr)
    # Multiply the above result with cnt and add the result to the lexicogrpc_rank.
    # Store it in the same variable lexicogrpc_rank.
    lexicogrpc_rank += cnt*f
# Print the lexicogrpc_rank to get the Lexicographic Rank of a given string.
print("The given String's {", gven_str,
      "} Lexicographic Rank = ", lexicogrpc_rank)
# Out:
# The given String's { kaka } Lexicographic Rank =  14

# %%
# Import math module using the import keyword.
import math
# Give the string as static input and store it in a variable.
gven_str = "btechgeeks"
# Take a variable to say lexicogrpc_rank and initialize its value to 1.
lexicogrpc_rank = 1
# Calculate the length of the given string using the len() function and decrease it by 1.
# Store it in another variable say str_lengt.
str_lengt = len(gven_str)-1
# Loop from 0 to the above length using the for loop.
for itr in range(0, str_lengt):
    # Inside the loop, take a variable to say cnt and initialize its value to 0.
    cnt = 0
    # Loop from the itr+1 to the above str_lengt (where itr is the iterator value of the parent
    # for loop) using the for loop.
    for k in range(itr+1, str_lengt+1):
      # Inside the loop, check if the character present at the iterator value of the parent for
      # loop is greater than the character present at the iterator value of the inner for
      # loop using the if conditional statement.
        if gven_str[itr] > gven_str[k]:
         # If the statement is true, then increment the value of the above-initialized cnt by 1.
            cnt += 1
    # Calculate the factorial of (str_lengt - itr) using the math.factorial() function and
    # store it in another variable. (where itr is the iterator value of the parent for loop)
    f = math.factorial(str_lengt-itr)
    # Multiply the above result with cnt and add the result to the lexicogrpc_rank.
    # Store it in the same variable lexicogrpc_rank.
    lexicogrpc_rank += cnt*f
# Print the lexicogrpc_rank to get the Lexicographic Rank of a given string.
print("The given String's {", gven_str,
      "} Lexicographic Rank = ", lexicogrpc_rank)
# Out:
# The given String's { btechgeeks } Lexicographic Rank =  328009

# %%
import math
g='kaka'
l=1
s=len(g)-1

for i in range(0,len(g)):
    c=0

    for x in range(i+1,s+1):
        if g[i]>g[x]:
            c+=1
            print(c)
        
    f=math.factorial(s-i)
    l+=c*f
print(l)
# Out:
# 1
# 2
# 1
# 14

# %%
for  i in range(1,11):
    print(f'{8}*{i}'+'=',8*i)
# Out:
# 8*1= 8
# 8*2= 16
# 8*3= 24
# 8*4= 32
# 8*5= 40
# 8*6= 48
# 8*7= 56
# 8*8= 64
# 8*9= 72
# 8*10= 80

# %%
l=[1,2,0,30,0,3,0,2,1,2,3,4,5,6,7,0,1,0,9,8,0]
l1=[]
c=[]
for i in range(len(l)):
    if l[i]==0:
        c.append(l[i])

    else:
        l1.append(l[i])
for i in range(len(c)):
    l1.append(c[i])
l1
# Out:
# [1, 2, 30, 3, 2, 1, 2, 3, 4, 5, 6, 7, 1, 9, 8, 0, 0, 0, 0, 0, 0]

# %%
given_list = [7, 2, 0, 34, 56, 12, 0, 5, 6, 8, 0, 0, 9, 0, 1, 2, 4, 5]
# print the list before modifictaion
print("the list before modification :")
print(given_list)
# Take a count, say zeroCount, and set it to 0
index = 0
# Traverse the given array/list using for loop.
for eleme in range(len(given_list)):
    if(given_list[eleme] != 0):
        given_list[index], given_list[eleme] = given_list[eleme], given_list[index]
        index = index+1
# print the list after modifictaion
print("the list after modification :")
print(given_list)
# Out:
# the list before modification :
# [7, 2, 0, 34, 56, 12, 0, 5, 6, 8, 0, 0, 9, 0, 1, 2, 4, 5]
# 0
# 0 0
# 1
# 1 1
# 2
# 3
# 2 3
# 4
# 3 4
# 5
# 4 5
# 6
# 7
# 5 7
# 8
# 6 8
# 9
# 7 9
# 10
# 11
# 12
# 8 12
# 13
# 14
# 9 14
# 15
# 10 15
# 16
# 11 16
# 17
# 12 17
# the list after modification :
# [7, 2, 34, 56, 12, 5, 6, 8, 9, 1, 2, 4, 5, 0, 0, 0, 0, 0]

# %%
g=[7, 2, 0, 34, 56, 12, 0, 5, 6, 8, 0, 0, 9, 0, 1, 2, 4, 5]
i=0
for e in range(len(g)):
    if g[e]!=0:
        g[i],g[e]=g[e],g[i]
        i+=1
print(g)
# Out:
# [7, 2, 34, 56, 12, 5, 6, 8, 9, 1, 2, 4, 5, 0, 0, 0, 0, 0]

# %%
l=[1,2,3,4,5,6,7,8,9]
n=5
for i in range(len(l)-1):
    for y in range(i+1,len(l)):
        if l[i]+l[y]==5:
            print(l[i],l[y])
# Out:
# 1 4
# 2 3

# %%
t =[7, 9, 6, 8, 7, 5, 9, 4, 3, 2, 11, 19, 23, 4, 5, 8, 6, 3 ,2, 9, 7,]    
n=7
m=8
for i in range(len(t)):
    if t[i]==n:
        res=i
        break
    if t[i]==m:- 
        res2=i
        break
res
res2
# Out:
# 9

# %%
x=open('file.txt','w')
x.write('Hello Sir')
x.close()

# %%
x=open('file.txt','w')
x.writelines(['Hello\n','Sir\n','How\n','are\n','you\n'])
x.close()

# %%
x=open('file.txt','a')
xx=x.write('hello')
print(xx)
# Out:
# 5
