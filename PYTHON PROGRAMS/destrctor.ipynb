# %%
class Employee:
    Ecount=0
    def __init__(self,name):
        print('init')
        self.name=name
        Employee.Ecount+=1
    def __del__(self):
        print('__del__')
        Employee.Ecount-=1
        
obj1=Employee('Vishnu')
obj2=Employee('harshad')

print(Employee.Ecount)
del obj1
print(Employee.Ecount)
# Out:
# init
# init
# 2
# __del__
# 1

# %%
x=set()
x.update({'1':'s','g':'7'})

# %%
n='we are indians'
xx=n.split()
x=[]
for i in range(len(xx)):
    x.append([len(xx[i]),xx[i]])

x=n.split()
for i in range(len(x)-1):
    for y in range(len(x)-1-i):
        if x[y]<x[y+1]:
            x[y],x[y+1]=x[y+1],x[y]
x
# Out:
# ['we', 'indians', 'are']

# %%
n='we are indians'
x=n.split()
for i in range(len(x)-1):
    for y in range(len(x)-1-i):
        if x[y]>x[y+1]:
            x[y],x[y+1]=x[y+1],x[y]
x
# Out:
# ['are', 'indians', 'we']

# %%
n='engineering'
c=0
pc=''
for i in range(len(n)):
    if n[i] not in pc:
        pc+=n[i]
        print(f'{n[i]}:{n.count(n[i])}')
# Out:
# e:3
# n:3
# g:2
# i:2
# r:1

# %%
n=[1,2,3,4,5,6,7]
for i in range(len(n)//2):
    n[i],n[len(n)-1-i]=n[len(n)-1-i],n[i]
n
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
def sum(n):
    if n==0:
        return (9)
    return (n%10)+sum(n//10)
obj=sum(1234)
obj
# Out:
# 19

# %%
encoded_string = "a3b2c1"
decoded_string = decoder(encoded_string)
print(decoded_string)  # Output: "aaabbc"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 encoded_string = "a3b2c1"
# ----> 2 decoded_string = decoder(encoded_string)
#       3 print(decoded_string)  # Output: "aaabbc"
#
# NameError: name 'decoder' is not defined

# %%
n='a3b2c1'
l=[]
m=[]
for i in range(len(n)):
    if n[i].isdigit():
        l.append(n[i])
    else:
        m.append(n[i])
for y in range(len(l)):
    c=l[y]
    print(m[y]*int(c),end='')
# Out:
# aaabbc

# %%
l='123942232'
s=set(l)
x=str(l)
y=sorted(s)
y[-4]
# Out:
# '2'

# %%
l='123942232'
s=set(l)
x=list(s)
for i in range(len(x)-1): 
    for y in range(len(x)-1-i):
        if x[y]>x[y+1]:
            x[y],x[y+1]=x[y+1],x[y]
print(int(x[-4]))
# Out:
# 2

# %%
n='atASD)(*&^%$#@!rew@12'
res=''
num=''
spe=''
for i in range(len(n)):
    if 'a'<=n[i]<='z':
        res+=n[i]
    elif 'A'<=n[i]<='Z':
        res+=n[i]
    elif '0'<=n[i]<='9':
        num+=n[i]
    else:
        spe+=n[i]
res
num
spe
# Out:
# ')(*&^%$#@!@'

# %%
n='atASD)(*&^%$#@!rew@12'
res=''
num=''
spe=''
for i in range(len(n)):
    if n[i]==n[i].isdigit():
        res+=n[i]
    print(res)

# %%
n='Vishnu@9959'
import re
x=re.match('[a-zA-Z]+(\W+\d+|\d+\W)[a-zA-Z]*',n)
if x and len(n)>8 and ' ' not in n:
    print('Valid')
else:
    print('Not valid')
# Out:
# Valid

# %%
n=input('')

# %%
with open('json.txt','r') as file:
    for i in file:
        print(len(i))
# Out:
# 67

# %%
with open('json.txt','r') as file:
    c=0
    for i in file:
        
        c+=1

# %%
with open('json.txt','r') as file:
    fil

# %%
def sample(arg):
    print(arg)
    def inner():
        arg()
    return inner
@sample
def demo():
    print('Demo')
demo()
# Out:
# <function demo at 0x07CB93D0>
# Demo

# %%
a='gfds'
b='gfds'
print(id(a))
print(id(b))
a='gh'
print(id(a))
print(id(b))
# Out:
# 115921824
# 115921824
# 71652224
# 115921824

# %%
l='190-5566543a:10(1)'
# Out:
# '190-5566543a:10'

# %%
a=(12,[1,3])
a[1][0]=10
a
# Out:
# (12, [10, 3])

# %%
s={1,2,[1,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 s={1,2,[1,4]}
#
# TypeError: unhashable type: 'list'

# %%
a={1:2,1:5,2:5,1:6}
a
# Out:
# {1: 6, 2: 5}

# %%
import unittest
class  Demo(unittest.TestCase):
    def setUpClass(self):
        print('Setup')
    def test_m(self):
        print('Test')
    def tearDownClass(self):
        print('Tear')
unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument 'c:\\Users\\golla\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-2362014CIfwNmIHFq.json'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File c:\Users\golla\AppData\Local\Programs\Python\Python310-32\lib\argparse.py:1859, in ArgumentParser.parse_known_args(self, args, namespace)
#    1858 try:
# -> 1859     namespace, args = self._parse_known_args(args, namespace)
#    1860 except ArgumentError:
#
# File c:\Users\golla\AppData\Local\Programs\Python\Python310-32\lib\argparse.py:2068, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2067     # consume the next optional and any arguments for it
# ...

# %%
n='234213'
x=n[len(n)-2:]
y=n[:2]
print(y+x)
# Out:
# 2313

# %%
n='matter we are the people'
x=n.split()
xx=sorted(x)
xx
# Out:
# ['are', 'matter', 'people', 'the', 'we']

# %%
class name:
    def __init__(self,name,age,gender):
        self.n
# Out:
# 22

# %%
"""FIRTST ENTER FOR OPENEDX.ORG  CLICK ON GET STARTED AND SELECT ON OPENEDX REGISTER AND SIGNIN
 AFETR THAT CLICK ON CREATE A COURSE VIDEO IN THAT WE HAVE LIKE cNAME AND ORGANISATION AND AND RUN TIME COURSE NAME AND CLICK AND CREATE AND THEN SCHEDULE COURSE C_D C_T C_ED CE_TSAVE CHANGEGS  CREATE A SECTION WE WANT CREATE A SECTION  WE HAVE OPTIONS FOR VISIBILITY AND  HIDE FROM LEARNERS SAVE SUBSECTION   """
# Out:
# 'FIRTST ENTER FOR OPENEDX.ORG  CLICK ON GET STARTED AND SELECT ON OPENEDX REGISTER AND SIGNIN\n AFETR THAT CLICK ON CREATE A COURSE VIDEO IN THAT WE HAVE LIKE cNAME AND ORGANISATION AND AND RUN TIME COURSE NAME AND CLICK AND CREATE AND THEN SCHEDULE COURSE C_D C_T C_ED CE_TSAVE CHANGEGS  CREATE A SECTION WE WANT CREATE A SECTION  WE HAVE OPTIONS FOR VISIBILITY AND  HIDE FROM LEARNERS SAVE SUBSECTION   '

# %%
n=int(input())
for i in range(2,n//2+1):
    try:

        if n%2==0:
            raise Exception('Not Prime')
        else:
            print('Prime')
            break
    except  Exception as E:
        print(E)
        break
else:
    print('Prime')
# finally:
# print('End')
# Out:
# Prime

# %%
def fahrenheit_from(celsius):
    """Convert Celsius to Fahrenheit degrees."""
    try:
        fahrenheit = float(celsius) * 9 / 5 + 32
        fahrenheit = round(fahrenheit, 3)  # Round to three decimal places
        return str(fahrenheit)
    except ValueError:
        return "invalid input"

if __name__ == "__main__":
    celsius = input("Celsius: ")
    print("Fahrenheit:", fahrenheit_from(celsius))
# Out:
# Fahrenheit: 132.8

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def index():
    return "Congratulations, it's a web app!"

@app.route("/")
def fahrenheit_from(celsius):
    """Convert Celsius to Fahrenheit degrees."""
    try:
        fahrenheit = float(celsius) * 9 / 5 + 32
        fahrenheit = round(fahrenheit, 3)  # Round to three decimal places
        return str(fahrenheit)
    except ValueError:
        return "invalid input"

if __name__ == "__main__":
    app.run(host="127.0.0.1", port=8080, debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from flask import Flask
#       3 app = Flask(__name__)
#       5 @app.route("/")
#       6 def index():
#
# ModuleNotFoundError: No module named 'flask'

# %%
he produces whitepapers--highly technical and focused documents on product specifications.

# %%
pip install pytest
# Out:
# ...
#      ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#      -------------------------- ----------- 225.3/323.6 kB 6.9 MB/s eta 0:00:01
#      -------------------------------------- 323.6/323.6 kB 5.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pytest
def fun(x):
    return x+5
def test_method():
    assert fun(3)==8
xx=test_method()
print(xx)
# Out:
# None

# %%
import pytest
@pytest.mark.one 
def test_method1():
    x=5
    y=10
    assert x==y


@pytest.mark.two
def test_method():
    a=15 
    b=20
    assert a+5==b
test_method()
test_method1()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 16
#      14     assert a+5==b
#      15 test_method()
# ---> 16 test_method1()
#
# Cell In[18], line 7, in test_method1()
#       5 x=5
#       6 y=10
# ----> 7 assert x==y
#
# AssertionError:

# %%
"""mkdir cd touch head tail grep diff ping history cat cp mv vi toc ls ls *.txt"""
# Out:
# hello

# %%
def is_even(number):
    division_result = number / 2
    if division_result.is_integer():
        return True
    else:
        return False

print(is_even(6))
print(is_even(7))
# Out:
# True
# False

# %%
ysgouda2008 Paapu@143

# %%
6/2
# Out:
# 3.0

# %%
import unittest

def add_numbers(x, y):
    return x + y

class TestAddNumbers(unittest.TestCase):
    def test_add_positive_numbers(self):
        result = add_numbers(5, 10)
        self.assertEqual(result, 15)

    def test_add_negative_numbers(self):
        result = add_numbers(-5, -10)
        self.assertEqual(result, -15)

    def test_add_zero_to_number(self):
        result = add_numbers(10, 0)
        self.assertEqual(result, 10)

if __name__ == '__main__':
    unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument 'c:\\Users\\golla\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-17284wnC0aJ43b0g4.json'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File c:\Users\golla\AppData\Local\Programs\Python\Python310-32\lib\argparse.py:1859, in ArgumentParser.parse_known_args(self, args, namespace)
#    1858 try:
# -> 1859     namespace, args = self._parse_known_args(args, namespace)
#    1860 except ArgumentError:
#
# File c:\Users\golla\AppData\Local\Programs\Python\Python310-32\lib\argparse.py:2068, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2067     # consume the next optional and any arguments for it
# ...
