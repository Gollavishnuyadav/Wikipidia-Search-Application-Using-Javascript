# %%
import pandas as pd
weather_data={'date':['01-10-2012','02-02-2012','03-05-2016'],'temperature':[10,13,'n.a.'],'windspeed':[1,2,3],'Event':['Rain','Sunny','summer']}
xx=pd.DataFrame(weather_data)
def convert_people_cell(cell):
    if cell=='n.a.':
        return '10'
    return cell
n='golla'
xx=convert_people_cell(n)
xx
# Out:
# 'golla'

# %%
import pandas as pd
d={'a':[1],'b':[2],'c':[3],'d':[123]}
xx=pd.DataFrame(d)
xx
# Out:
#    a  b  c    d
# 0  1  2  3  123

# %%
n=int(input())
c=0
while True:
    if n>1:
        for i in range(2,n//2+1):
            if n%i==0:
                break
        else:
            c+=1
            if c==2:
                print(n)
                break
    n+=1
# Out:
# 3

# %%
n=int(input())
c=0
while True:
    if n>1:
        for i in range(2,n//2+1):
            if n%i==0:
                break
        else:
            c+=1
            if c==2:
                print(n)
                break
    n+=1
# Out:
# 3

# %%
import pandas as pd
xx=pd.read_csv("a.")
xx
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 xx=pd.read_csv("a.csv")
#       3 xx
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
l=[1,2,3]
m=[2,3,4]
xx=list(map(lambda x,y:x+y,l,m))
xx
# Out:
# [3, 5, 7]

# %%
import pandas as pd
Indian_weather={'Name':['Golla','Vishnu','Yadav'],'temp':[1,2,3],'Wind':[1,2,3]}
xx=pd.DataFrame(Indian_weather)
xx
# Out:
#      Name  temp  Wind
# 0   Golla     1     1
# 1  Vishnu     2     2
# 2   Yadav     3     3

# %%
import pandas as pd
Indian_weathe={'Name':['Golla','Vishneu','Yadav'],'temp':[1,2,3],'Wind':[1,2,3]}
xx=pd.DataFrame(Indian_weathe)
xx
# Out:
#       Name  temp  Wind
# 0    Golla     1     1
# 1  Vishneu     2     2
# 2    Yadav     3     3

# %%
pd.concat([Indian_weather,Indian_weathe])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pd.concat([Indian_weather,Indian_weathe])
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# ...

# %%
# function that takes in string argument as parameter
def comp(PROMPT, MaxToken=50, outputs=3):
	# using OpenAI's Completion module that helps execute
	# any tasks involving text
	response = openai.Completion.create(
		# model name used here is text-davinci-003
		# there are many other models available under the
		# umbrella of GPT-3
		model="text-davinci-003",
		# passing the user input
		prompt=PROMPT,
		# generated output can have "max_tokens" number of tokens
		max_tokens=MaxToken,
		# number of outputs generated in one call
		n=outputs
	)
	# creating a list to store all the outputs
	output = list()
	for k in response['choices']:
		output.append(k['text'].strip())
	return output

# %%
a='abcd11gdf15hnnn678hh4'
import re
re.findall('\d+',a)
# Out:
# ['11', '15', '678', '4']
