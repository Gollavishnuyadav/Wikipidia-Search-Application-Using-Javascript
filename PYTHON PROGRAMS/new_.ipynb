# %%
n=input('Enter the string')
if len(n)%2==0 and len(n)>1:
    print(len(n))
    for i in range(1,len(n)):
        print(type(i))
        if i%2==1 and n[i].isdigit():
            print('True')
        else:
            if i%2==0 and n[i].isalpha():
                print('True')
                break
else:
    print('please enter the string')
# Out:
# 4
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
n = '5r6t7u8i9o'
numbers = ''
alphabets = ''

for char in n:
    if char.isdigit():
        if int(char) % 2 != 0:  # odd numbers
            numbers += char
    else:
        alphabets += char

print("Odd numbers:", numbers)
print("Alphabets:", alphabets)
# Out:
# Odd numbers: 579
# Alphabets: rtuio

# %%
n = '1a2c3d'

for i in range(len(n)):
    if i % 2 == 0 and not n[i].isalpha():
        print(f"Character at index {i} is not alphabetic.")
    elif i % 2 != 0 and not n[i].isdigit():
        print(f"Character at index {i} is not a digit.")
# Out:
# Character at index 0 is not alphabetic.
# Character at index 1 is not a digit.
# Character at index 2 is not alphabetic.
# Character at index 3 is not a digit.
# Character at index 4 is not alphabetic.
# Character at index 5 is not a digit.

# %%
import re
n='+91-9959647036'
xx=re.findall('[+]91-[6-9]\d{9}',n)
if xx and len(n)>8 and ' ' not in n:
    print('Valid')
else:
    print('Invalid')
# Out:
# Valid

# %%
import re
n='Vishnu@995.9'
xx=re.findall('[a-zA-Z]+(\W+\d+|\d+\W+)[a-zA-Z]*',n)
if xx:
    print('Valid')
else:
    print('NOT CURRECT PASSWORD')
# Out:
# Valid

# %%
n='vishnu is me'
res=''
x=n.split()
for i in range(len(x)):
    if i==0:
        res=res+''+x[i][::-1]
res
# Out:
# 'unhsiv'

# %%
y = {1: 100, 2: 90, 3: 80, 4: 100, 5:80}
l=[]
d={}
for k,v in y.items():
    if v not in l:
        l.append(v)
        d[k]=v
d
# Out:
# {1: 100, 2: 90, 3: 80}

# %%
y =  {'Hello': 'one', 'this': 'two', 'igs': 'three', 'btechgeeks': 'four'}
z =  {'good': 'five', 'hello': 'six', 'igs': 'three'}
for k,v in y.items():
    for i,j in z.items():
        if k==i:
            print(f'{i}:{j}')
# Out:
# igs:three

# %%
# y = {10: 'jan', 20: 'feb', 30: 'march', 40: 'April', 50: 'may'}
y = {'monday': 1, 'tuesday': 2, 'wednesday': 3}
d={}
for i,j in y.items():
    d[j]=[i]
d
# Out:
# {1: ['monday'], 2: ['tuesday'], 3: ['wednesday']}

# %%
y = {'a': 1, 'b': 5, 'c': 2, 'd': 4, 'e': 7, 'f': 2}
d=y.values()
x=1
for i in d:
    x=x*i
x
# Out:
# 560

# %%
# given some random key
keyelement = input("Enter some random key = ")
# given some random value of int datatype
valueelement = int(input("Enter some random value of integer type = "))
# Declare a dictionary and set its initial value to empty using {} or dict()
sampledictionary = {}
# To add the key-value pair to the dictionary, use the update() function.
sampledictionary.update({keyelement: valueelement})
# The Modified dictionary is printed
print("The dictionary after adding the key =", keyelement,
      "and value element =", valueelement, " is : ")
print(sampledictionary)
# Out:
# The dictionary after adding the key = ji and value element = 12  is :
# {'ji': 12}

# %%
n=input()
m=int(input())
d={}
d[n]=m
d
# Out:
# {'Hello': 123}

# %%
d={i:i*i for i in range(1,11)}
d
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
# given number
numb = int(input("Enter some random number = "))
# using dictionary comprehension
resultdict = {k: k*k for k in range(1, numb+1)}
# printing the resultant dictionary
print('printing the resultant dictionary :')
for key,value in resultdict.items():
    print("key =",key,"value =",value)
# Out:
# printing the resultant dictionary :
# key = 1 value = 1
# key = 2 value = 4
# key = 3 value = 9
# key = 4 value = 16

# %%
g = "hello this is btechgeeks online to programming platform to read the coding articles specially python language"
x=g.split()
l=[]
for i in x:
    for y in i:
        if i[0]==y:
            print(f'{y}:::',[i])
# Out:
# h::: ['hello']
# t::: ['this']
# i::: ['is']
# b::: ['btechgeeks']
# o::: ['online']
# t::: ['to']
# p::: ['programming']
# p::: ['platform']
# t::: ['to']
# r::: ['read']
# t::: ['the']
# c::: ['coding']
# a::: ['articles']
# s::: ['specially']
# p::: ['python']
# l::: ['language']

# %%
# given string
given_string = "hello this is btechgeeks online programming platform to read the coding articles specially python language"
# Split the given string into words using split() function
# Convert this into list using list() function.
listString = given_string.split()
# Declare a dictionary which is empty using {} or dict()
resultdict = {}
# Traverse the list String
for stringword in listString:
  # checking if the first character of the word exists in dictionary resultdict keys or not
    if(stringword[0] not in resultdict.keys()):
        resultdict[stringword[0]] = []
        # adding this character to the resultdict
        resultdict[stringword[0]].append(stringword)
    else:
      # If it is present, add the word to the associated sublist as the value.
        if(stringword not in resultdict[stringword[0]]):
            resultdict[stringword[0]].append(stringword)
for key, value in resultdict.items():
    print(key, ":::", value)
# Out:
# h ::: ['hello']
# t ::: ['this', 'to', 'the']
# i ::: ['is']
# b ::: ['btechgeeks']
# o ::: ['online']
# p ::: ['programming', 'platform', 'python']
# r ::: ['read']
# c ::: ['coding']
# a ::: ['articles']
# s ::: ['specially']
# l ::: ['language']

# %%
print('hello')

# %%
s='green-red-black-white'
res=''
l=[]
o='black-green-red-white'
for i in range(len(s)):
    if s[i]!='-':
        res+=s[i]
    else:
        l.append(res)
        res=''
l.append(res)
l.sort()
xx='-'.join(l)
xx
# Out:
# 'black-green-red-white'

# %%
def permutations(s,i=0):
    if i==len(s):
        print(' '.join(s))
    for j in range(i,len(s)):
        w=[c for c in s]
        w[i],w[j]=w[j],w[i]
        permutations(s,i+1)
permutations('run')
# Out:
# r u n
# r u n
# r u n
# r u n
# r u n
# r u n

# %%
pip install emoji
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: C:\Users\ASUS\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/361.8 kB ? eta -:--:--
#      ----------- -------------------------- 112.6/361.8 kB 2.2 MB/s eta 0:00:01
#      --------------------------------- ---- 317.4/361.8 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------  358.4/361.8 kB 3.7 MB/s eta 0:00:01
#      -------------------------------------- 361.8/361.8 kB 2.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
from emoji import emojize
print(emojize("::"))
# Out:
# :facebook:

# %%
help(emoji)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 help(emoji)
#
# NameError: name 'emoji' is not defined

# %%
# Python code to find the co-ordinates of
# the contours detected in an image.
import numpy as np
import cv2

# Reading image
font = cv2.FONT_HERSHEY_COMPLEX
img2 = cv2.imread('test.jpg', cv2.IMREAD_COLOR)

# Reading same image in another
# variable and converting to gray scale.
img = cv2.imread('test.jpg', cv2.IMREAD_GRAYSCALE)

# Converting image to a binary image
# ( black and white only image).
_, threshold = cv2.threshold(img, 110, 255, cv2.THRESH_BINARY)

# Detecting contours in image.
contours, _= cv2.findContours(threshold, cv2.RETR_TREE,
							cv2.CHAIN_APPROX_SIMPLE)

# Going through every contours found in the image.
for cnt in contours :

	approx = cv2.approxPolyDP(cnt, 0.009 * cv2.arcLength(cnt, True), True)

	# draws boundary of contours.
	cv2.drawContours(img2, [approx], 0, (0, 0, 255), 5)

	# Used to flatted the array containing
	# the co-ordinates of the vertices.
	n = approx.ravel()
	i = 0

	for j in n :
		if(i % 2 == 0):
			x = n[i]
			y = n[i + 1]

			# String containing the co-ordinates.
			string = str(x) + " " + str(y)

			if(i == 0):
				# text on topmost co-ordinate.
				cv2.putText(img2, "Arrow tip", (x, y),
								font, 0.5, (255, 0, 0))
			else:
				# text on remaining co-ordinates.
				cv2.putText(img2, string, (x, y),
						font, 0.5, (0, 255, 0))
		i = i + 1

# Showing the final image.
cv2.imshow('image2', img2)

# Exiting the window if 'q' is pressed on the keyboard.
if cv2.waitKey(0) & 0xFF == ord('q'):
	cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 4
#       1 # Python code to find the co-ordinates of
#       2 # the contours detected in an image.
#       3 import numpy as np
# ----> 4 import cv2
#       6 # Reading image
#       7 font = cv2.FONT_HERSHEY_COMPLEX
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: C:\Users\ASUS\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import cv2

# Read the image.
img = cv2.imread('taj.jpg')

# Apply bilateral filter with d = 15,
# sigmaColor = sigmaSpace = 75.
bilateral = cv2.bilateralFilter(img, 15, 75, 75)

# Save the output.
cv2.imwrite('taj_bilateral.jpg', bilateral)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import cv2
#       3 # Read the image.
#       4 img = cv2.imread('taj.jpg')
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: C:\Users\ASUS\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import unittest

class TestStringMethods(unittest.TestCase):

    def test_upper(self):
        self.assertEqual('foo'.upper(), 'FOO')

    def test_isupper(self):
        self.assertTrue('FOO'.isupper())
        self.assertFalse('Foo'.isupper())

    def test_split(self):
        s = 'hello world'
        self.assertEqual(s.split(), ['hello', 'world'])
        # check that s.split fails when the separator is not a string
        with self.assertRaises(TypeError):
            s.split(2)

if __name__ == '__main__':
    unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument 'c:\\Users\\ASUS\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-15580JqPWkAdYvRKM.json'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\argparse.py:1866, in ArgumentParser.parse_known_args(self, args, namespace)
#    1865 try:
# -> 1866     namespace, args = self._parse_known_args(args, namespace)
#    1867 except ArgumentError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\argparse.py:2079, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
# ...

# %%
import unittest

class TestStringMethods(unittest.TestCase):

    def test_upper(self):
        self.assertEqual('foo'.upper(), 'FOO')

    def test_isupper(self):
        self.assertTrue('FOO'.isupper())
        self.assertFalse('Foo'.isupper())

    def test_split(self):
        s = 'hello world'
        self.assertEqual(s.split(), ['hello', 'world'])
        # check that s.split fails when the separator is not a string
        with self.assertRaises(TypeError):
            s.split(2)

if __name__ == '__main__':
    unittest.main()
